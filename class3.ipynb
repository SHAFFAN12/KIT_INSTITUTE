# %%
import pandas as pd
import numpy as np

table = pd.DataFrame({
    "Name":["Ahmed","Sufyan","Ali","hamza",np.NAN],
    "f.Name":["ALi","Ahmed","Sufyan","Riaz",np.NAN],
    "RollNo":[11,np.NAN,33,44,np.NAN],
    "Class":[np.NAN,2,3,1,np.NAN],
    "Marks":["80","70","90","50",np.NAN]

})
table
# Out:
#      Name  f.Name  RollNo  Class Marks
# 0   Ahmed     ALi    11.0    NaN    80
# 1  Sufyan   Ahmed     NaN    2.0    70
# 2     Ali  Sufyan    33.0    3.0    90
# 3   hamza    Riaz    44.0    1.0    50
# 4     NaN     NaN     NaN    NaN   NaN

# %%
table.loc[1]
# Out:
# Name      Sufyan
# f.Name     Ahmed
# RollNo       NaN
# Class        2.0
# Marks         70
# Name: 1, dtype: object

# %%
table['Name']
# Out:
# 0     Ahmed
# 1    Sufyan
# 2       Ali
# 3     hamza
# 4    Waseeq
# Name: Name, dtype: object

# %%
new_table =table.dropna(how="all")

new_table
# Out:
#      Name  f.Name  RollNo  Class Marks
# 0   Ahmed     ALi    11.0    NaN    80
# 1  Sufyan   Ahmed     NaN    2.0    70
# 2     Ali  Sufyan    33.0    3.0    90
# 3   hamza    Riaz    44.0    1.0    50

# %%
newTable2 = table.fillna(4)
newTable2
# Out:
#      Name  f.Name  RollNo  Class Marks
# 0   Ahmed     ALi    11.0    4.0    80
# 1  Sufyan   Ahmed     4.0    2.0    70
# 2     Ali  Sufyan    33.0    3.0    90
# 3   hamza    Riaz    44.0    1.0    50
# 4       4       4     4.0    4.0     4

# %%
data = pd.read_excel('/content/canada_per_capita_income.xlsx')
data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
data.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
data.isnull()
# Out:
#      year  per capita income (US$)
# 0   False                    False
# 1   False                    False
# 2   False                    False
# 3   False                    False
# 4   False                    False
# 5   False                    False
# 6   False                    False
# 7   False                    False
# 8   False                    False
# 9   False                    False
# 10  False                    False
# 11  False                    False
# 12  False                    False
# 13  False                    False
# 14  False                    False
# 15  False                    False
# 16  False                    False
# 17  False                    False
# 18  False                    False
# 19  False                    False
# 20  False                    False
# 21  False                    False
# 22  False                    False
# 23  False                    False
# 24  False                    False
# 25  False                    False
# ...
