# %% [markdown]
# # **PART C **

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ***a***

# %%
data = pd.read_csv('/content/pjppTV.csv',encoding="latin")
data
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %% [markdown]
# # ***b***

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Prefix          18018 non-null  object
#  2   FirstName       18148 non-null  object
#  3   LastName        18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18018 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  object
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.8+ MB

# %%
data.describe()
# Out:
#         CustomerKey  TotalChildren
# count  18148.000000   18148.000000
# mean   20247.470465       1.843619
# std     5336.245656       1.613203
# min    11000.000000       0.000000
# 25%    15626.750000       0.000000
# 50%    20252.500000       2.000000
# 75%    24868.250000       3.000000
# max    29483.000000       5.000000

# %%
data.isnull().sum()
# Out:
# CustomerKey         0
# Prefix            130
# FirstName           0
# LastName            0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %% [markdown]
# # ***c***

# %%
data['Prefix'] = data['Prefix'].fillna('unknown')
data.head(26)
# Out:
#     CustomerKey   Prefix  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0         11000      MR.        JON     YANG    4/8/1966             M      M
# 1         11001      MR.     EUGENE    HUANG   5/14/1965             S      M
# 2         11002      MR.      RUBEN   TORRES   8/12/1965             M      M
# 3         11003      MS.    CHRISTY      ZHU   2/15/1968             S      F
# 4         11004     MRS.  ELIZABETH  JOHNSON    8/8/1968             S      F
# 5         11005      MR.      JULIO     RUIZ    8/5/1965             S      M
# 6         11007      MR.      MARCO    MEHTA    5/9/1964             M      M
# 7         11008     MRS.      ROBIN  VERHOFF    7/7/1964             S      F
# 8         11009      MR.    SHANNON  CARLSON    4/1/1964             S      M
# 9         11010      MS.  JACQUELYN   SUAREZ    2/6/1964             S      F
# 10        11011      MR.     CURTIS       LU   11/4/1963             M      M
# ...

# %%
data['Gender'] = data['Gender'].fillna('unknown')
data
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***d***

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

data['Gender'] = enc.fit_transform(data['Gender'])
data
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        328     YANG    4/8/1966             M
# 1            11001    MR.        224    HUANG   5/14/1965             S
# 2            11002    MR.        563   TORRES   8/12/1965             M
# 3            11003    MS.        140      ZHU   2/15/1968             S
# 4            11004   MRS.        212  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.        629     TANG    7/4/1958             M
# 18144        29480   MRS.        498     RAJI  11/10/1960             S
# 18145        29481    MR.        278     SURI    1/5/1960             S
# 18146        29482    MR.        144    ZHANG    3/5/1959             M
# 18147        29483    MR.        349  NAVARRO   12/8/1959             M
#
#        Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %% [markdown]
# # ***e***

# %%
import matplotlib.pyplot as plt

# %%
y1=data['EducationLevel']
x1=data['TotalChildren']

# %%
plt.bar(x1,y1)
plt.xlabel('Education Level')
plt.ylabel('TotalChildren')
plt.title('Bar')
plt.show()

# %% [markdown]
# # ***PART D***

# %%
data2 = pd.DataFrame({
    "Passenger_id":[1,2,3,4,5],
    "name":["ali","ahmed","ayesha","John","sarah"],
    "gender":["Male","Male","Female","Male","Female"],
    "cabin":[np.nan,"C85",np.nan,"C123",np.nan],
    "Age":[22.01,38.01,26.00,35.01,35.00]
})
data2
# Out:
#    Passenger_id    name  gender cabin    Age
# 0             1     ali    Male   NaN  22.01
# 1             2   ahmed    Male   C85  38.01
# 2             3  ayesha  Female   NaN  26.00
# 3             4    John    Male  C123  35.01
# 4             5   sarah  Female   NaN  35.00

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Passenger_id  5 non-null      int64
#  1   name          5 non-null      object
#  2   gender        5 non-null      object
#  3   cabin         2 non-null      object
#  4   Age           5 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 328.0+ bytes

# %%
data2['cabin'] = data2['cabin'].replace(np.nan,"not-specified")
data2
# Out:
#    Passenger_id    name  gender          cabin    Age
# 0             1     ali    Male  not-specified  22.01
# 1             2   ahmed    Male            C85  38.01
# 2             3  ayesha  Female  not-specified  26.00
# 3             4    John    Male           C123  35.01
# 4             5   sarah  Female  not-specified  35.00

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

data2['gender'] = enc.fit_transform(data2['gender'])
data2
# Out:
#    Passenger_id    name  gender          cabin    Age
# 0             1     ali       1  not-specified  22.01
# 1             2   ahmed       1            C85  38.01
# 2             3  ayesha       0  not-specified  26.00
# 3             4    John       1           C123  35.01
# 4             5   sarah       0  not-specified  35.00

# %%
y1=data2['Age']
x1=data2['Passenger_id']

plt.bar(x1,y1)
plt.xlabel('Age')
plt.ylabel('	Passenger_id')
plt.title('Bar')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
