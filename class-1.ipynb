# %%
import pandas as pd

# %%
data = pd.read_excel("//content/YixJih.xlsx")
# Out:
# <ipython-input-14-367efd91e88b>:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   data = pd.read_excel("//content/YixJih.xlsx")

# %%
data
# Out:
#      EventID                                  EventName  \
# 0          1                                  Chernobyl
# 1          2                              Pearl Harbour
# 2          3                          World War 1 began
# 3          4                           World War 1 ends
# 4          5             The UK declares war on Germany
# ..       ...                                        ...
# 454      587  Further enlargement of the European Union
# 455      589        A Northern Ireland Executive formed
# 456      590       Tony Blair resigns as Prime Minister
# 457      591          Prohibition of smoking in England
# 458      592        Seventh and final Harry Potter book
#
#                                           EventDetails  EventDate  \
# 0    Reactor 4 at a nuclear power plant in Chernoby... 1986-04-26
# 1    Japan launched an attack dubbed ‘Operation Z’ ... 1941-12-07
# 2    Often referred to as The Great War, World War ... 1914-07-28
# ...
